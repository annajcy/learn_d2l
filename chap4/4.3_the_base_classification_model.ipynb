# %%
import torch
import abc 
from torch import nn
from torch.utils import data
from abc import ABC, abstractmethod

# %%
class SoftmaxClassifier(ABC):
    @abstractmethod
    def forward(self, x):
        pass
    
    @abstractmethod
    def accuracy(self, y_hat, y):
        pass
